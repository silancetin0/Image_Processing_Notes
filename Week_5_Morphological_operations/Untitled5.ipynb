# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
my_original_img = cv2.imread("./binary.png",0)
my_kernel = np.ones((5,5),dtype=np.uint8)

my_erosion_img = cv2.erode(my_original_img, my_kernel, iterations=1)

fig = plt.figure(figsize=(10,7))
rows= 1
columns=2

fig.add_subplot(rows, columns,1)
plt.imshow(my_original_img, cmap="gray")
plt.axis('off')
plt.title("Original Image")

fig.add_subplot(rows, columns,2)
plt.imshow(my_erosion_img, cmap="gray")
plt.axis('off')
plt.title('Equalized Histogram Image')
# Out:
# Text(0.5, 1.0, 'Equalized Histogram Image')

# %%
#genişleme (dilation)
my_dilation_img = cv2.dilate(my_original_img, my_kernel, iterations=1)

fig = plt.figure(figsize=(10,7))
rows= 1
columns=3

fig.add_subplot(rows, columns,1)
plt.imshow(my_original_img, cmap="gray")
plt.axis('off')
plt.title("Original Image")

fig.add_subplot(rows, columns,2)
plt.imshow(my_original_img, cmap="gray")
plt.axis('off')
plt.title("Original Image")

fig.add_subplot(rows, columns,3)
plt.imshow(my_dilation_img, cmap="gray")
plt.axis('off')
plt.title('DİLATİON Image')
# Out:
# Text(0.5, 1.0, 'DİLATİON Image')

# %%
#açma (opening)
new_img = cv2.imread("./binary_with_text.png",0)
white_noise = np.random.randint(0,2,size=new_img.shape)

white_noise = np.random.randint(0,2,size=new_img.shape [0:2])
white_noise = white_noise*255

# %%
 plt.imshow(my_white_noise,cmap="gray"=
plt.axis("off")
plt.title("white and black ımage")
# Out:
# Text(0.5, 1.0, 'white anfd black Image')

# %%
my_noised_img = new_img + white_noise

fig = plt.figure(figsize=(10,7))
rows= 1
columns=2

fig.add_subplot(rows, columns,1)
plt.imshow(new_img, cmap="gray")
plt.axis('off')
plt.title("Original Image")

fig.add_subplot(rows, columns,2)
plt.imshow(my_noised_img, cmap="gray")
plt.axis('off')
plt.title('Equalized Histogram Image')
# Out:
# Text(0.5, 1.0, 'Equalized Histogram Image')

# %%
my_opening_img =cv2.morphologyEx(my_noised_img.astype(np.float32), cv2.MORPH_OPEN,my_kernel)

# %%
fig = plt.figure(figsize=(10,7))
rows= 1
columns=3

fig.add_subplot(rows, columns,1)
plt.imshow(new_img, cmap="gray")
plt.axis('off')
plt.title("Original Image")

fig.add_subplot(rows, columns,2)
plt.imshow(my_noised_img, cmap="gray")
plt.axis('off')
plt.title("NOİSED Image")

fig.add_subplot(rows, columns,3)
plt.imshow(my_opening_img, cmap="gray")
plt.axis('off')
plt.title('OPENİNG Image')
# Out:
# Text(0.5, 1.0, 'OPENİNG Image')

# %%
# 4. morfolojık closing kapatma açma 
my_black_noise = np.random.randint(0,2,size=my_original_img.shape [0:2])
my_black_noise = my_black_noise *-255

plt.imshow(my_black_noise,cmap="gray")
plt.axis("off")
plt.title("my black noised ımage")
# Out:
# Text(0.5, 1.0, 'my black noised ımage')

# %%
my_black_noise_img = my_black_noise + new_img ## siyah gürültü toplamı

# %%
my_black_noise_img[my_black_noise_img <= -255]= 0

# %%
my_closing_img= cv2.morphologyEx(my_black_noise_img.astype(np.float32),cv2.MORPH_CLOSE,my_kernel)

fig = plt.figure(figsize=(10,7))
rows= 1
columns=3

fig.add_subplot(rows, columns,1)
plt.imshow(new_img, cmap="gray")
plt.axis('off')
plt.title("Original Image")

fig.add_subplot(rows, columns,2)
plt.imshow(my_black_noise_img, cmap="gray")
plt.axis('off')
plt.title(" BLACK NOİSED Image")

fig.add_subplot(rows, columns,3)
plt.imshow(my_closing_img, cmap="gray")
plt.axis('off')
plt.title('CLOSİNG Image')
# Out:
# Text(0.5, 1.0, 'CLOSİNG Image')

# %%
## 5.morfolojik işlem gradyan renklerin ani degişimlerini gösteriyor
 

my_gradient_img_1 = cv2.morphologyEx(my_original_img, cv2.MORPH_GRADIENT ,my_kernel)
my_gradient_img_2 = cv2.morphologyEx(new_img, cv2.MORPH_GRADIENT ,my_kernel)

# %%
fig = plt.figure(figsize=(10,7))
rows= 2
columns=2

fig.add_subplot(rows, columns,1)
plt.imshow(my_original_img, cmap="gray")
plt.axis('off')
plt.title("Original Image")

fig.add_subplot(rows, columns,2)
plt.imshow(my_gradient_img_1, cmap="gray")
plt.axis('off')
plt.title(" GRANDIENT Image 1")

fig.add_subplot(rows, columns,3)
plt.imshow(new_img, cmap="gray")
plt.axis('off')
plt.title('CORİGİNAL Image 2')

fig.add_subplot(rows, columns,4)
plt.imshow(my_gradient_img_2, cmap="gray")
plt.axis('off')
plt.title(" GRANDIENT Image 2")
# Out:
# Text(0.5, 1.0, ' GRANDIENT Image 2')
